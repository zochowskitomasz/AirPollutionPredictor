# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# %%
def read_weather_data(path):
    df = pd.read_csv(path, sep=',')
    df.columns=['time', 'temp', 'hum', 'press', 'wind']
    df['time'] = pd.to_datetime(df['time'], errors='coerce')
    return df

# %%
weather_2025 = read_weather_data('../downloading_data/warsaw_weather_2025_hourly.csv')

# %%
def read_smog_data(path):
    df = pd.read_csv(path, sep=',', header=None)
    df.drop(columns=[2], inplace=True)
    df.columns = ['time', 'pm25']
    df['time'] = pd.to_datetime(df['time'], errors='coerce')
    df.dropna(inplace=True)
    return df

# %%
pm25_2025 = read_smog_data('../downloading_data/gios-pjp-data.csv')

# %%
pm25_2025.head()
# Out:
#                  time  pm25
# 0 2025-01-01 01:00:00  65.7
# 1 2025-01-01 02:00:00  31.5
# 2 2025-01-01 03:00:00  20.2
# 3 2025-01-01 04:00:00  21.7
# 4 2025-01-01 05:00:00  20.8

# %%
df2025 = pd.merge(weather_2025, pm25_2025, on='time', how='inner')

# %%
df2025['month'] = df2025['time'].dt.month

# %%
df2025
# Out:
#                     time  temp  hum  press  wind  pm25  month
# 0    2025-01-01 01:00:00     2   68   1020    18  65.7      1
# 1    2025-01-01 02:00:00     2   67   1020    19  31.5      1
# 2    2025-01-01 03:00:00     2   67   1019    20  20.2      1
# 3    2025-01-01 04:00:00     3   66   1018    21  21.7      1
# 4    2025-01-01 05:00:00     3   64   1018    22  20.8      1
# ...                  ...   ...  ...    ...   ...   ...    ...
# 6525 2025-10-28 20:00:00     8   73   1005    18   7.7     10
# 6526 2025-10-28 21:00:00     7   77   1004    17   6.9     10
# 6527 2025-10-28 22:00:00     7   83   1004    17   6.7     10
# 6528 2025-10-28 23:00:00     8   89   1003    17   7.4     10
# 6529 2025-10-29 00:00:00     8   87   1004    19   8.0     10
#
# [6530 rows x 7 columns]

# %%
df2025.describe()
# Out:
#                                 time         temp          hum        press  \
# count                           6530  6530.000000  6530.000000  6530.000000
# mean   2025-06-11 08:00:48.514548480    13.099847    65.509495  1015.679173
# min              2025-01-01 01:00:00    -4.000000    16.000000   986.000000
# 25%              2025-04-06 18:15:00     8.000000    51.000000  1011.000000
# 50%              2025-06-14 22:30:00    13.000000    66.000000  1016.000000
# 75%              2025-08-21 22:45:00    19.000000    82.000000  1021.000000
# max              2025-10-29 00:00:00    35.000000   100.000000  1040.000000
# std                              NaN     7.403506    18.903297     7.536086
#
#               wind         pm25        month
# count  6530.000000  6530.000000  6530.000000
# mean     12.957427    12.855191     5.840276
# min       0.000000     2.400000     1.000000
# 25%       9.000000     7.000000     4.000000
# 50%      12.000000     9.900000     6.000000
# 75%      17.000000    14.800000     8.000000
# max      32.000000    91.600000    10.000000
# std       5.753876     9.974677     2.762083

# %%
X = df2025[['temp', 'press', 'hum', 'wind', 'month']]
y = df2025['pm25']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist = {
    'regressor__n_estimators': np.arange(200, 1200, 200), #number of trees
    'regressor__max_depth': np.arange(3, 11), #maximum depth of each tree
    'regressor__learning_rate': [0.01, 0.05, 0.1, 0.2], #step size shrinkage - how much the model is updated at each step
    'regressor__subsample': [0.5, 0.7, 1.0], #fraction of samples used for fitting the individual base learners
    'regressor__colsample_bytree': [0.5, 0.7, 1.0] #fraction of features used for fitting the individual base learners
}
pipeline1 = Pipeline(steps=[
    ('regressor', XGBRegressor(
        random_state=42,
    ))
])

search = RandomizedSearchCV(
    pipeline1,
    param_dist,
    n_iter=40,
    scoring='neg_mean_absolute_error',
    cv=5,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=7, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.6s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=7, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.6s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=7, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.6s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=7, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.7s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=7, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.7s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=1000, regressor__subsample=0.5; total time=   1.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=1000, regressor__subsample=0.5; total time=   1.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=1000, regressor__subsample=0.5; total time=   1.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=1000, regressor__subsample=0.5; total time=   1.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=1000, regressor__subsample=0.5; total time=   1.5s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=3, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   2.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.9s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.9s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   2.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   2.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=0.7; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.7s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   2.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   2.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.6s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=800, regressor__subsample=0.7; total time=   1.0s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=800, regressor__subsample=0.7; total time=   1.0s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=1.0; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=800, regressor__subsample=0.7; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=800, regressor__subsample=0.7; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=10, regressor__n_estimators=800, regressor__subsample=0.7; total time=   1.0s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.8s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.9s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.8s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.9s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.8s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=9, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.7s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=9, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.7s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=9, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.7s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=9, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.7s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=9, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.7s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=7, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.5s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=10, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.5s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=7, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=7, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=600, regressor__subsample=0.7; total time=   1.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=7, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=7, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=600, regressor__subsample=0.7; total time=   1.0s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=600, regressor__subsample=0.7; total time=   1.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=7, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=7, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=1.0; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=600, regressor__subsample=0.7; total time=   1.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=10, regressor__n_estimators=600, regressor__subsample=0.7; total time=   1.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=800, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=800, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=800, regressor__subsample=1.0; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=800, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=4, regressor__n_estimators=800, regressor__subsample=1.0; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.5; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.5; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.5; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.5; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.1, regressor__max_depth=9, regressor__n_estimators=800, regressor__subsample=0.5; total time=   1.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=200, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.5; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.5; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.05, regressor__max_depth=5, regressor__n_estimators=600, regressor__subsample=0.5; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=3, regressor__n_estimators=600, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=3, regressor__n_estimators=600, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=3, regressor__n_estimators=600, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=3, regressor__n_estimators=600, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.3s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.2, regressor__max_depth=3, regressor__n_estimators=600, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.7, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=800, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=6, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.1, regressor__max_depth=5, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.1s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=8, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=8, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=8, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=8, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=1.0, regressor__learning_rate=0.05, regressor__max_depth=8, regressor__n_estimators=400, regressor__subsample=0.7; total time=   0.4s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   0.2s
# [CV] END regressor__colsample_bytree=0.5, regressor__learning_rate=0.01, regressor__max_depth=4, regressor__n_estimators=1000, regressor__subsample=1.0; total time=   0.2s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('regressor',
#                                               XGBRegressor(base_score=None,
#                                                            booster=None,
#                                                            callbacks=None,
#                                                            colsample_bylevel=None,
#                                                            colsample_bynode=None,
#                                                            colsample_bytree=None,
#                                                            device=None,
#                                                            early_stopping_rounds=None,
#                                                            enable_categorical=False,
#                                                            eval_metric=None,
#                                                            feature_types=None,
#                                                            feature_weights=None,
#                                                            gamma=None,
#                                                            grow_policy=None,
#                                                            importance_typ...
#                                                            num_parallel_tree=None, ...))]),
#                    n_iter=40, n_jobs=-1,
#                    param_distributions={'regressor__colsample_bytree': [0.5,
#                                                                         0.7,
#                                                                         1.0],
#                                         'regressor__learning_rate': [0.01, 0.05,
#                                                                      0.1, 0.2],
#                                         'regressor__max_depth': array([ 3,  4,  5,  6,  7,  8,  9, 10]),
#                                         'regressor__n_estimators': array([ 200,  400,  600,  800, 1000]),
#                                         'regressor__subsample': [0.5, 0.7,
#                                                                  1.0]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=2)

# %%
param_grid2 = {
    'regressor__n_estimators': [100, 200, 300],
    'regressor__max_depth': [None, 10, 20, 30]
}

pipeline2 = Pipeline(steps=[
    ('regressor', RandomForestRegressor(
        random_state=42,
    ))
])

grid = GridSearchCV(
    pipeline2,
    param_grid2,
    scoring='neg_mean_absolute_error',
    cv=5,
    n_jobs=-1,
    verbose=2
)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END regressor__max_depth=None, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__max_depth=None, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__max_depth=None, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__max_depth=None, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__max_depth=None, regressor__n_estimators=100; total time=   1.2s
# [CV] END regressor__max_depth=None, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__max_depth=None, regressor__n_estimators=200; total time=   2.4s
# [CV] END regressor__max_depth=None, regressor__n_estimators=200; total time=   2.5s
# [CV] END regressor__max_depth=10, regressor__n_estimators=100; total time=   0.7s
# [CV] END regressor__max_depth=None, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__max_depth=None, regressor__n_estimators=200; total time=   2.3s
# [CV] END regressor__max_depth=10, regressor__n_estimators=100; total time=   0.6s
# [CV] END regressor__max_depth=10, regressor__n_estimators=100; total time=   0.6s
# [CV] END regressor__max_depth=10, regressor__n_estimators=100; total time=   0.7s
# [CV] END regressor__max_depth=None, regressor__n_estimators=300; total time=   3.1s
# [CV] END regressor__max_depth=None, regressor__n_estimators=300; total time=   3.2s
# [CV] END regressor__max_depth=None, regressor__n_estimators=300; total time=   3.2s
# [CV] END regressor__max_depth=10, regressor__n_estimators=100; total time=   0.8s
# [CV] END regressor__max_depth=10, regressor__n_estimators=200; total time=   1.4s
# [CV] END regressor__max_depth=10, regressor__n_estimators=200; total time=   1.4s
# [CV] END regressor__max_depth=None, regressor__n_estimators=300; total time=   3.2s
# [CV] END regressor__max_depth=None, regressor__n_estimators=300; total time=   3.2s
# [CV] END regressor__max_depth=10, regressor__n_estimators=200; total time=   1.4s
# [CV] END regressor__max_depth=10, regressor__n_estimators=200; total time=   1.4s
# [CV] END regressor__max_depth=10, regressor__n_estimators=200; total time=   1.4s
# [CV] END regressor__max_depth=20, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__max_depth=10, regressor__n_estimators=300; total time=   2.1s
# [CV] END regressor__max_depth=20, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__max_depth=20, regressor__n_estimators=100; total time=   1.3s
# [CV] END regressor__max_depth=10, regressor__n_estimators=300; total time=   2.1s
# [CV] END regressor__max_depth=10, regressor__n_estimators=300; total time=   2.1s
# [CV] END regressor__max_depth=10, regressor__n_estimators=300; total time=   2.2s
# [CV] END regressor__max_depth=20, regressor__n_estimators=100; total time=   1.0s
# [CV] END regressor__max_depth=10, regressor__n_estimators=300; total time=   2.4s
# [CV] END regressor__max_depth=20, regressor__n_estimators=100; total time=   1.3s
# [CV] END regressor__max_depth=20, regressor__n_estimators=200; total time=   2.1s
# [CV] END regressor__max_depth=20, regressor__n_estimators=200; total time=   2.4s
# [CV] END regressor__max_depth=20, regressor__n_estimators=200; total time=   2.4s
# [CV] END regressor__max_depth=20, regressor__n_estimators=200; total time=   2.2s
# [CV] END regressor__max_depth=20, regressor__n_estimators=200; total time=   2.4s
# [CV] END regressor__max_depth=30, regressor__n_estimators=100; total time=   1.0s
# [CV] END regressor__max_depth=30, regressor__n_estimators=100; total time=   1.1s
# [CV] END regressor__max_depth=30, regressor__n_estimators=100; total time=   1.2s
# [CV] END regressor__max_depth=20, regressor__n_estimators=300; total time=   3.3s
# [CV] END regressor__max_depth=20, regressor__n_estimators=300; total time=   3.3s
# [CV] END regressor__max_depth=20, regressor__n_estimators=300; total time=   3.3s
# [CV] END regressor__max_depth=30, regressor__n_estimators=100; total time=   1.2s
# [CV] END regressor__max_depth=30, regressor__n_estimators=100; total time=   1.2s
# [CV] END regressor__max_depth=20, regressor__n_estimators=300; total time=   3.5s
# [CV] END regressor__max_depth=20, regressor__n_estimators=300; total time=   3.5s
# [CV] END regressor__max_depth=30, regressor__n_estimators=200; total time=   2.4s
# [CV] END regressor__max_depth=30, regressor__n_estimators=200; total time=   2.6s
# [CV] END regressor__max_depth=30, regressor__n_estimators=200; total time=   2.5s
# [CV] END regressor__max_depth=30, regressor__n_estimators=200; total time=   2.6s
# [CV] END regressor__max_depth=30, regressor__n_estimators=200; total time=   2.4s
# [CV] END regressor__max_depth=30, regressor__n_estimators=300; total time=   3.3s
# [CV] END regressor__max_depth=30, regressor__n_estimators=300; total time=   3.3s
# [CV] END regressor__max_depth=30, regressor__n_estimators=300; total time=   3.2s
# [CV] END regressor__max_depth=30, regressor__n_estimators=300; total time=   2.8s
# [CV] END regressor__max_depth=30, regressor__n_estimators=300; total time=   2.8s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('regressor',
#                                         RandomForestRegressor(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 30],
#                          'regressor__n_estimators': [100, 200, 300]},
#              scoring='neg_mean_absolute_error', verbose=2)

# %%
RF = grid.best_estimator_

# %%
y_pred = RF.predict(X_test)

mse = round(mean_squared_error(y_test, y_pred),2)
rmse = round(np.sqrt(mean_squared_error(y_test, y_pred)),2)
mae = round(mean_absolute_error(y_test, y_pred),2)
r2 = round(r2_score(y_test, y_pred),2)

print(f"MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R2: {r2}")
# Out:
# MSE: 17.63, RMSE: 4.2, MAE: 2.64, R2: 0.82

# %%
y_pred = RF.predict(X_test)

mse = round(mean_squared_error(y_test, y_pred),2)
rmse = round(np.sqrt(mean_squared_error(y_test, y_pred)),2)
mae = round(mean_absolute_error(y_test, y_pred),2)
r2 = round(r2_score(y_test, y_pred),2)

print(f"MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R2: {r2}")
# Out:
# MSE: 17.63, RMSE: 4.2, MAE: 2.64, R2: 0.82

# %%
XGB = search.best_estimator_

# %%
y_pred = XGB.predict(X_test)

mse = round(mean_squared_error(y_test, y_pred),2)
rmse = round(np.sqrt(mean_squared_error(y_test, y_pred)),2)
mae = round(mean_absolute_error(y_test, y_pred),2)
r2 = round(r2_score(y_test, y_pred),2)

print(f"MSE: {mse}, RMSE: {rmse}, MAE: {mae}, R2: {r2}")
# Out:
# MSE: 16.45, RMSE: 4.06, MAE: 2.53, R2: 0.83

# %%
import pandas as pd
print(f"Evaluated on date: {pd.Timestamp.now()}")
# Out:
# Evaluated on date: 2026-01-14 12:28:20.803716
